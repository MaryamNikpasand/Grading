# %% [markdown]
# <a href="https://colab.research.google.com/github/MaryamNikpasand/Grading/blob/main/Joint/GradingJoints.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import tensorflow as tf
# !pip install -q -U keras-tuner
import keras_tuner as kt
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import layers
from pathlib import Path
from scipy import ndimage
from tensorflow.keras import regularizers
from tensorflow.keras import initializers
# Out:
#      |████████████████████████████████| 98 kB 5.4 MB/s

# %%
def read_files(filepath):
  """Read and load volume"""
  # Read file
  scan=plt.imread(filepath)
  plt.imshow(scan, cmap = plt.cm.gray)
  plt.show()
#   Get raw data
  return scan

# def normalize(volume):
#   """normalize the volume
#      The max value for normalization is: np.mean(max_all)+2*np.std(max_all)
#      The min value of all images in this dataset is 0
# """
#   min=0
#   max=1007.2348186941014
#   volume[volume<min]=min
#   volume[volume>max]=max
#   volume=(volume-min)/(max-min)
#   volume=volume.astype("float32")
#   return volume

# def normalize(volume):
#   """normalize the volume
#      Normalize with max and min of each image
# """
#   min=np.min(volume)
#   max=np.max(volume)
#   volume=(volume-min)/(max-min)
#   volume=volume.astype("float32")
#   return volume

def normalize(volume):
  """normalize the volume
     Normalize with mean and std of each image
"""
  Mean=np.mean(volume)
  Std=np.std(volume)
  volume=(volume-Mean)/Std
  volume=volume.astype("float32")
  return volume

def resize_volume(img):
  """Resize across z-axis"""
  # Set the desired depth
  desired_width = 64
  desired_height = 64
  # Get current depth
  current_width = img.shape[0]
  current_height = img.shape[-1]
  # Compute depth factor
  width = current_width / desired_width
  height = current_height / desired_height
  width_factor = 1 / width
  height_factor = 1 / height
  # Resize across z-axis
  img = ndimage.zoom(img, (width_factor, height_factor), order=1)
  # resize_and_rescale = tf.keras.Sequential([
  #   layers.experimental.preprocessing.Resizing(desired_width, desired_height, desired_depth)])
  # img = resize_and_rescale(tf.expand_dims(img, axis=-1))
  return img

def process_scan(path):
  """Read and resize volume"""
  # Read scan
  volume=read_files(path)
  # Normalize
  volume=normalize(volume)
  volume=resize_volume(volume)
  volume=tf.expand_dims(volume,axis=-1) #  Adding an extra dimension to the images to have them in (x,x,1) format 
  return volume

# %%
filepath = '/content/drive/MyDrive/PhD/Barocas/grading/LumbarDiscJointScoring_Main/ImageSelection/Joints/Takahashi/grade1/T1_TSE_TRA__0004_009.ima_left.png'
scan = process_scan(filepath)
scan.shape
# Out:
# TensorShape([64, 64, 1])

# %%
# Folder "Joint" consist of MRI scans having Joint images,
Joint_paths = dict()
filepath_Joint='/content/drive/MyDrive/PhD/Barocas/grading/LumbarDiscJointScoring_Main/ImageSelection/Joints/Takahashi'
for x in os.listdir(filepath_Joint):
    for y in os.listdir(os.path.join(filepath_Joint,x)):
        if x not in Joint_paths:
            Joint_paths[x] = [os.path.join(filepath_Joint, x, y)]
        else:
            Joint_paths[x].append(os.path.join(filepath_Joint, x, y))

print("Joint['grade1']:: " + str(len(Joint_paths['grade1'])))
print("Joint['grade2']:: " + str(len(Joint_paths['grade2'])))
print("Joint['grade3']:: " + str(len(Joint_paths['grade3'])))
print("Joint['grade4']:: " + str(len(Joint_paths['grade4'])))

# Read and process the scans.
Joint_grade1 = np.array([process_scan(path) for path in Joint_paths['grade1']])
Joint_grade2 = np.array([process_scan(path) for path in Joint_paths['grade2']])
Joint_grade3 = np.array([process_scan(path) for path in Joint_paths['grade3']])
Joint_grade4 = np.array([process_scan(path) for path in Joint_paths['grade4']])
# Out:
# Joint['grade1']:: 926
# Joint['grade2']:: 841
# Joint['grade3']:: 462
# Joint['grade4']:: 148

# %%
# For the Joint images assign 1-5
Joint_grade1_labels=np.array([[1, 0, 0, 0] for _ in range(len(Joint_grade1))])
Joint_grade2_labels=np.array([[0, 1, 0, 0] for _ in range(len(Joint_grade2))])
Joint_grade3_labels=np.array([[0, 0, 1, 0] for _ in range(len(Joint_grade3))])
Joint_grade4_labels=np.array([[0, 0, 0, 1] for _ in range(len(Joint_grade4))])

Joint_grade1_train_limit=int(len(Joint_paths['grade1'])*.9)
Joint_grade2_train_limit=int(len(Joint_paths['grade2'])*.9)
Joint_grade3_train_limit=int(len(Joint_paths['grade3'])*.9)
Joint_grade4_train_limit=int(len(Joint_paths['grade4'])*.9)

Joint_grade1_val_limit=int(len(Joint_paths['grade1'])*.1)+Joint_grade1_train_limit
Joint_grade2_val_limit=int(len(Joint_paths['grade2'])*.1)+Joint_grade2_train_limit
Joint_grade3_val_limit=int(len(Joint_paths['grade3'])*.1)+Joint_grade3_train_limit
Joint_grade4_val_limit=int(len(Joint_paths['grade4'])*.1)+Joint_grade4_train_limit

# Split data in the ratio 70-30 for training and validation.
x_train=np.concatenate((Joint_grade1[:Joint_grade1_train_limit],
                        Joint_grade2[:Joint_grade2_train_limit],
                        Joint_grade3[:Joint_grade3_train_limit],
                        Joint_grade4[:Joint_grade4_train_limit]),axis=0)

y_train=np.concatenate((Joint_grade1_labels[:Joint_grade1_train_limit],
                        Joint_grade2_labels[:Joint_grade2_train_limit],
                        Joint_grade3_labels[:Joint_grade3_train_limit],
                        Joint_grade4_labels[:Joint_grade4_train_limit]),axis=0)

x_val=np.concatenate((Joint_grade1[Joint_grade1_train_limit:],
                      Joint_grade2[Joint_grade2_train_limit:],
                      Joint_grade3[Joint_grade3_train_limit:],
                      Joint_grade4[Joint_grade4_train_limit:]),axis=0)

y_val=np.concatenate((Joint_grade1_labels[Joint_grade1_train_limit:],
                      Joint_grade2_labels[Joint_grade2_train_limit:],
                      Joint_grade3_labels[Joint_grade3_train_limit:],
                      Joint_grade4_labels[Joint_grade4_train_limit:]),axis=0)

print(
    "Number of samples in train and validation are %d and %d."
    % (x_train.shape[0], x_val.shape[0])
)

# Define data loaders
train_loader = tf.data.Dataset.from_tensor_slices((x_train, y_train ))
validation_loader = tf.data.Dataset.from_tensor_slices((x_val, y_val))
# Out:
# Number of samples in train and validation are 2137 and 240.

# %%
AUTOTUNE = tf.data.AUTOTUNE
batch_size = 32
train_dataset = (
    train_loader.shuffle(len(x_train))
    .batch(batch_size)
    .prefetch(buffer_size=AUTOTUNE)
)

# Only rescale.
validation_dataset = (
    validation_loader.shuffle(len(x_val))
    .batch(batch_size)
    .prefetch(buffer_size=AUTOTUNE)
)

# # Visualize a set of images
# import matplotlib.pyplot as plt
# plt.figure(figsize=(10, 10))
# for images,labels in train_dataset.take(1):
#   for i in range(9):
#     ax=plt.subplot(3,3,i+1)
#     plt.imshow(np.squeeze(images[i].numpy()),cmap='gray')
#     plt.title(int(labels[i]))
#     plt.axis("off")

# Data augmentation
data_augmentation=keras.Sequential([
                                    layers.experimental.preprocessing.RandomFlip("horizontal"),
                                    layers.experimental.preprocessing.RandomRotation(.1)
])

# %%
def get_model_3D_CTscans(input_shape):
  """Build a 2D convolutional neural network model."""

  inputs = keras.Input(shape=input_shape)
  print(inputs.shape)
  # Image augmentation
  x=data_augmentation(inputs)

  x=layers.Conv2D(filters=64,kernel_size=3,strides=1,padding='valid', activation='relu',kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4))(x)
  x=layers.MaxPool2D(pool_size=2)(x)
  x=layers.BatchNormalization()(x)

  x=layers.Conv2D(filters=64,kernel_size=3,activation='relu',kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4))(x)
  x=layers.MaxPool2D(pool_size=2)(x)
  x=layers.BatchNormalization()(x)

  x=layers.Conv2D(filters=128,kernel_size=3,activation='relu',kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4))(x)
  x=layers.MaxPool2D(pool_size=2)(x)
  x=layers.BatchNormalization()(x)

  x=layers.Conv2D(filters=256,kernel_size=3,activation='relu',kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4))(x)
  x=layers.MaxPool2D(pool_size=2)(x)
  x=layers.BatchNormalization()(x)

  x=layers.GlobalAveragePooling2D()(x)
  x=layers.Dense(units=512,activation='relu', kernel_regularizer=regularizers.l2(.001))(x)
  x=layers.Dropout(.3)(x)

  outputs=layers.Dense(units=4,activation='softmax')(x)

  model=keras.Model(inputs,outputs,name='2dcnn')
  return model

image_size=(64,64)
model=get_model_3D_CTscans(input_shape=image_size + (1,))
model.summary()
# Out:
# (None, 64, 64, 1)
# Model: "2dcnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 1)]       0
#
#  sequential (Sequential)     (None, 64, 64, 1)         0
#
#  conv2d (Conv2D)             (None, 62, 62, 64)        640
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 64)       0
#  )
#
#  batch_normalization (BatchN  (None, 31, 31, 64)       256
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 14, 14, 64)       256
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 6, 6, 128)        512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 256)         295168
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 2, 2, 256)        1024
#  hNormalization)
#
#  global_average_pooling2d (G  (None, 256)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               131584
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 542,276
# Trainable params: 541,252
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
# %% Compile the model
initial_learning_rate=1e-4
lr_schedule=keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=initial_learning_rate,decay_steps=1e5,decay_rate=.96,staircase=True)

model.compile(
    loss="binary_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=lr_schedule),
    metrics=['accuracy'])

# Define callbacks
directory = "3D_CTscan" # Save the entire model as a SavedModel.
parent_dir = os.getcwd() # Parent Directory path
path = os.path.join(parent_dir, directory) # Path
os.makedirs(path,exist_ok=True) # Create the directory
checkpoint_path = Path(os.path.join(path,'2d_image_classification.h5'))
checkpoint_cb=keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,monitor='val_accuracy',save_best_only=True)

epochs=50
history=model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=epochs,
    shuffle=True,
    verbose=2,
    callbacks=[checkpoint_cb],
)
# Out:
# Epoch 1/50
# 67/67 - 13s - loss: 1.0495 - accuracy: 0.3435 - val_loss: 0.9850 - val_accuracy: 0.3542 - 13s/epoch - 192ms/step
# Epoch 2/50
# 67/67 - 1s - loss: 0.9866 - accuracy: 0.3968 - val_loss: 0.9734 - val_accuracy: 0.3542 - 697ms/epoch - 10ms/step
# Epoch 3/50
# 67/67 - 1s - loss: 0.9656 - accuracy: 0.4024 - val_loss: 1.0113 - val_accuracy: 0.4042 - 775ms/epoch - 12ms/step
# Epoch 4/50
# 67/67 - 1s - loss: 0.9477 - accuracy: 0.4221 - val_loss: 1.0082 - val_accuracy: 0.3792 - 693ms/epoch - 10ms/step
# Epoch 5/50
# 67/67 - 1s - loss: 0.9354 - accuracy: 0.4328 - val_loss: 1.0105 - val_accuracy: 0.4083 - 754ms/epoch - 11ms/step
# Epoch 6/50
# 67/67 - 1s - loss: 0.9269 - accuracy: 0.4431 - val_loss: 0.9608 - val_accuracy: 0.4333 - 754ms/epoch - 11ms/step
# Epoch 7/50
# 67/67 - 1s - loss: 0.9126 - accuracy: 0.4375 - val_loss: 0.9370 - val_accuracy: 0.4417 - 748ms/epoch - 11ms/step
# Epoch 8/50
# 67/67 - 1s - loss: 0.8989 - accuracy: 0.4605 - val_loss: 0.9259 - val_accuracy: 0.4583 - 757ms/epoch - 11ms/step
# Epoch 9/50
# 67/67 - 1s - loss: 0.8927 - accuracy: 0.4562 - val_loss: 0.9136 - val_accuracy: 0.4542 - 679ms/epoch - 10ms/step
# Epoch 10/50
# 67/67 - 1s - loss: 0.8803 - accuracy: 0.4553 - val_loss: 0.9023 - val_accuracy: 0.4583 - 682ms/epoch - 10ms/step
# Epoch 11/50
# 67/67 - 1s - loss: 0.8656 - accuracy: 0.4773 - val_loss: 0.8933 - val_accuracy: 0.4625 - 770ms/epoch - 11ms/step
# Epoch 12/50
# 67/67 - 1s - loss: 0.8599 - accuracy: 0.4675 - val_loss: 0.8934 - val_accuracy: 0.4375 - 685ms/epoch - 10ms/step
# Epoch 13/50
# 67/67 - 1s - loss: 0.8479 - accuracy: 0.4740 - val_loss: 0.8773 - val_accuracy: 0.4083 - 679ms/epoch - 10ms/step
# Epoch 14/50
# 67/67 - 1s - loss: 0.8413 - accuracy: 0.4731 - val_loss: 0.8751 - val_accuracy: 0.4208 - 685ms/epoch - 10ms/step
# Epoch 15/50
# 67/67 - 1s - loss: 0.8297 - accuracy: 0.4942 - val_loss: 0.8639 - val_accuracy: 0.4375 - 689ms/epoch - 10ms/step
# Epoch 16/50
# 67/67 - 1s - loss: 0.8257 - accuracy: 0.4764 - val_loss: 0.8590 - val_accuracy: 0.4083 - 686ms/epoch - 10ms/step
# Epoch 17/50
# 67/67 - 1s - loss: 0.8100 - accuracy: 0.4951 - val_loss: 0.8520 - val_accuracy: 0.4583 - 674ms/epoch - 10ms/step
# Epoch 18/50
# 67/67 - 1s - loss: 0.8040 - accuracy: 0.5068 - val_loss: 0.8486 - val_accuracy: 0.4500 - 697ms/epoch - 10ms/step
# Epoch 19/50
# 67/67 - 1s - loss: 0.8001 - accuracy: 0.4956 - val_loss: 0.8462 - val_accuracy: 0.4292 - 684ms/epoch - 10ms/step
# Epoch 20/50
# 67/67 - 1s - loss: 0.7887 - accuracy: 0.4993 - val_loss: 0.8372 - val_accuracy: 0.4208 - 676ms/epoch - 10ms/step
# Epoch 21/50
# 67/67 - 1s - loss: 0.7797 - accuracy: 0.5082 - val_loss: 0.8328 - val_accuracy: 0.4333 - 697ms/epoch - 10ms/step
# Epoch 22/50
# 67/67 - 1s - loss: 0.7740 - accuracy: 0.5016 - val_loss: 0.8281 - val_accuracy: 0.4500 - 687ms/epoch - 10ms/step
# Epoch 23/50
# 67/67 - 1s - loss: 0.7664 - accuracy: 0.5171 - val_loss: 0.8140 - val_accuracy: 0.4375 - 690ms/epoch - 10ms/step
# Epoch 24/50
# 67/67 - 1s - loss: 0.7594 - accuracy: 0.5213 - val_loss: 0.8194 - val_accuracy: 0.4292 - 681ms/epoch - 10ms/step
# Epoch 25/50
# 67/67 - 1s - loss: 0.7490 - accuracy: 0.5194 - val_loss: 0.8127 - val_accuracy: 0.4375 - 677ms/epoch - 10ms/step
# Epoch 26/50
# 67/67 - 1s - loss: 0.7458 - accuracy: 0.5227 - val_loss: 0.8017 - val_accuracy: 0.4417 - 684ms/epoch - 10ms/step
# Epoch 27/50
# 67/67 - 1s - loss: 0.7413 - accuracy: 0.5190 - val_loss: 0.8201 - val_accuracy: 0.3917 - 679ms/epoch - 10ms/step
# Epoch 28/50
# 67/67 - 1s - loss: 0.7291 - accuracy: 0.5386 - val_loss: 0.8006 - val_accuracy: 0.4500 - 692ms/epoch - 10ms/step
# Epoch 29/50
# 67/67 - 1s - loss: 0.7250 - accuracy: 0.5325 - val_loss: 0.7932 - val_accuracy: 0.4542 - 682ms/epoch - 10ms/step
# Epoch 30/50
# 67/67 - 1s - loss: 0.7187 - accuracy: 0.5475 - val_loss: 0.7968 - val_accuracy: 0.4458 - 685ms/epoch - 10ms/step
# Epoch 31/50
# 67/67 - 1s - loss: 0.7130 - accuracy: 0.5428 - val_loss: 0.7867 - val_accuracy: 0.4042 - 709ms/epoch - 11ms/step
# Epoch 32/50
# 67/67 - 1s - loss: 0.7071 - accuracy: 0.5363 - val_loss: 0.7748 - val_accuracy: 0.4292 - 681ms/epoch - 10ms/step
# Epoch 33/50
# 67/67 - 1s - loss: 0.6998 - accuracy: 0.5498 - val_loss: 0.7815 - val_accuracy: 0.3917 - 692ms/epoch - 10ms/step
# Epoch 34/50
# 67/67 - 1s - loss: 0.6980 - accuracy: 0.5349 - val_loss: 0.7842 - val_accuracy: 0.4208 - 682ms/epoch - 10ms/step
# Epoch 35/50
# 67/67 - 1s - loss: 0.6877 - accuracy: 0.5625 - val_loss: 0.7840 - val_accuracy: 0.4292 - 695ms/epoch - 10ms/step
# Epoch 36/50
# 67/67 - 1s - loss: 0.6826 - accuracy: 0.5695 - val_loss: 0.7775 - val_accuracy: 0.4292 - 679ms/epoch - 10ms/step
# Epoch 37/50
# 67/67 - 1s - loss: 0.6814 - accuracy: 0.5550 - val_loss: 0.7751 - val_accuracy: 0.4333 - 684ms/epoch - 10ms/step
# Epoch 38/50
# 67/67 - 1s - loss: 0.6768 - accuracy: 0.5629 - val_loss: 0.7705 - val_accuracy: 0.4333 - 683ms/epoch - 10ms/step
# Epoch 39/50
# 67/67 - 1s - loss: 0.6673 - accuracy: 0.5784 - val_loss: 0.7631 - val_accuracy: 0.4333 - 679ms/epoch - 10ms/step
# Epoch 40/50
# 67/67 - 1s - loss: 0.6607 - accuracy: 0.5770 - val_loss: 0.7712 - val_accuracy: 0.4250 - 678ms/epoch - 10ms/step
# Epoch 41/50
# 67/67 - 1s - loss: 0.6504 - accuracy: 0.5723 - val_loss: 0.7826 - val_accuracy: 0.4042 - 696ms/epoch - 10ms/step
# Epoch 42/50
# 67/67 - 1s - loss: 0.6525 - accuracy: 0.5831 - val_loss: 0.7741 - val_accuracy: 0.3792 - 675ms/epoch - 10ms/step
# Epoch 43/50
# 67/67 - 1s - loss: 0.6474 - accuracy: 0.5948 - val_loss: 0.7688 - val_accuracy: 0.3708 - 689ms/epoch - 10ms/step
# Epoch 44/50
# 67/67 - 1s - loss: 0.6401 - accuracy: 0.6008 - val_loss: 0.7756 - val_accuracy: 0.4125 - 686ms/epoch - 10ms/step
# Epoch 45/50
# 67/67 - 1s - loss: 0.6360 - accuracy: 0.5985 - val_loss: 0.7703 - val_accuracy: 0.4333 - 675ms/epoch - 10ms/step
# Epoch 46/50
# 67/67 - 1s - loss: 0.6273 - accuracy: 0.6041 - val_loss: 0.7477 - val_accuracy: 0.4375 - 683ms/epoch - 10ms/step
# Epoch 47/50
# 67/67 - 1s - loss: 0.6266 - accuracy: 0.6032 - val_loss: 0.7584 - val_accuracy: 0.4208 - 683ms/epoch - 10ms/step
# Epoch 48/50
# 67/67 - 1s - loss: 0.6138 - accuracy: 0.6242 - val_loss: 0.7496 - val_accuracy: 0.4083 - 689ms/epoch - 10ms/step
# Epoch 49/50
# 67/67 - 1s - loss: 0.6127 - accuracy: 0.6280 - val_loss: 0.7548 - val_accuracy: 0.4042 - 681ms/epoch - 10ms/step
# Epoch 50/50
# 67/67 - 1s - loss: 0.6064 - accuracy: 0.6242 - val_loss: 0.7696 - val_accuracy: 0.4000 - 682ms/epoch - 10ms/step

# %%
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# %% Model
def get_model_Niemeyer_Paper(input_shape):
#   """Build a 2D convolutional neural network model."""

  inputs = keras.Input(shape=input_shape)
  # Image augmentation
  x=data_augmentation(inputs)

  x=layers.Conv2D(filters=32,kernel_size=3,strides=1,padding='same',
                  activation=layers.LeakyReLU(alpha=.01),
                  kernel_regularizer=regularizers.l2(5e-4),
                  kernel_initializer=initializers.HeNormal())(x)
  x=layers.BatchNormalization()(x)
  x=layers.Dropout(.2)(x)

  x=layers.Conv2D(filters=64,kernel_size=3,dilation_rate=2,strides=1,padding='same',
                  activation=layers.LeakyReLU(alpha=.01),
                  kernel_regularizer=regularizers.l2(5e-4),
                  kernel_initializer=initializers.HeNormal())(x)
  x=layers.BatchNormalization()(x)
  x=layers.Conv2D(filters=64,kernel_size=3,dilation_rate=2,strides=1,padding='same',
                  activation=layers.LeakyReLU(alpha=.01),
                  kernel_regularizer=regularizers.l2(5e-4),
                  kernel_initializer=initializers.HeNormal())(x)
  x=layers.BatchNormalization()(x)    
  x=layers.Dropout(.2)(x)
  x=layers.MaxPool2D(pool_size=2)(x)

  x=layers.Conv2D(filters=128,kernel_size=3,dilation_rate=2,strides=1,padding='same',
                  activation=layers.LeakyReLU(alpha=.01),
                  kernel_regularizer=regularizers.l2(5e-4),
                  kernel_initializer=initializers.HeNormal())(x)
  x=layers.BatchNormalization()(x)
  x=layers.Conv2D(filters=128,kernel_size=3,dilation_rate=2,strides=1,padding='same',
                  activation=layers.LeakyReLU(alpha=.01),
                  kernel_regularizer=regularizers.l2(5e-4),
                  kernel_initializer=initializers.HeNormal())(x)
  x=layers.BatchNormalization()(x)
  x=layers.Dropout(.2)(x)

  x=layers.Conv2D(filters=256,kernel_size=3,dilation_rate=3,strides=1,padding='same',
                  activation=layers.LeakyReLU(alpha=.01),
                  kernel_regularizer=regularizers.l2(5e-4),
                  kernel_initializer=initializers.HeNormal())(x)
  x=layers.BatchNormalization()(x)
  x=layers.Conv2D(filters=256,kernel_size=3,dilation_rate=3,strides=1,padding='same',
                  activation=layers.LeakyReLU(alpha=.01),
                  kernel_regularizer=regularizers.l2(5e-4),
                  kernel_initializer=initializers.HeNormal())(x)
  x=layers.BatchNormalization()(x)
  x=layers.Dropout(.2)(x)
  x=layers.MaxPool2D(pool_size=2)(x)

  x=layers.Conv2D(filters=512,kernel_size=3,strides=1,padding='valid',
                  activation=layers.LeakyReLU(alpha=.01),
                  kernel_regularizer=regularizers.l2(5e-4),
                  kernel_initializer=initializers.HeNormal())(x)
  x=layers.BatchNormalization()(x)
  x=layers.Dropout(.2)(x)

  x=layers.GlobalAveragePooling2D()(x)
  x=layers.Dense(units=512,activation='relu')(x)

  outputs=layers.Dense(units=4,activation='softmax')(x) #change this to softmax when working wiht gradings

  model=keras.Model(inputs,outputs,name='2dcnn')
  return model

image_size=(64,64)
model=get_model_Niemeyer_Paper(input_shape=image_size + (1,))
model.summary()
# Out:
# Model: "2dcnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 64, 64, 1)]       0
#
#  sequential (Sequential)     (None, 64, 64, 1)         0
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 32)        320
#
#  batch_normalization_4 (Batc  (None, 64, 64, 32)       128
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 64, 64, 32)        0
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 64)        18496
#
#  batch_normalization_5 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 64, 64, 64)        36928
#
#  batch_normalization_6 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 64, 64, 64)        0
#
#  max_pooling2d_4 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 128)       73856
#
#  batch_normalization_7 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 128)       147584
#
#  batch_normalization_8 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 32, 32, 128)       0
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 256)       295168
#
#  batch_normalization_9 (Batc  (None, 32, 32, 256)      1024
#  hNormalization)
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 256)       590080
#
#  batch_normalization_10 (Bat  (None, 32, 32, 256)      1024
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 32, 32, 256)       0
#
#  max_pooling2d_5 (MaxPooling  (None, 16, 16, 256)      0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 14, 14, 512)       1180160
#
#  batch_normalization_11 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 14, 14, 512)       0
#
#  global_average_pooling2d_1   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dense_3 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 2,613,060
# Trainable params: 2,610,180
# Non-trainable params: 2,880
# _________________________________________________________________

# %%
# %% Compile the model
epochs=50
initial_learning_rate=1e-3
num_steps=np.floor(len(x_train)/batch_size)
boundaries=[]
values=[initial_learning_rate]
indx=1
while indx<int(epochs/10):
    boundaries.append(indx*10*num_steps)
    values.append(initial_learning_rate/(10**(indx)))
    indx+=1

lr_schedule = keras.optimizers.schedules.PiecewiseConstantDecay(boundaries,values)
# lr_schedule=keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=initial_learning_rate,decay_steps=1e5,decay_rate=.96,staircase=True)

model.compile(
    # loss=tf.keras.losses.CategoricalCrossentropy(),
    loss="binary_crossentropy",
    optimizer=keras.optimizers.SGD(learning_rate=lr_schedule, momentum=.9),
    metrics=['accuracy'])

# Define callbacks
directory = "Niemeyer_Paper" # Save the entire model as a SavedModel.
parent_dir = os.getcwd() # Parent Directory path
path = os.path.join(parent_dir, directory) # Path
os.makedirs(path,exist_ok=True) # Create the directory
checkpoint_path = Path(os.path.join(path,'2d_image_classification.h5'))
checkpoint_cb=keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                              monitor='val_accuracy',
                                              verbose=1,
                                              save_best_only=True,
                                              save_weights_only=True
                                              )


history=model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=epochs,
    shuffle=True,
    verbose=2,
    callbacks=[checkpoint_cb],
)
# Out:
# Epoch 1/50
#
# Epoch 00001: val_accuracy improved from -inf to 0.36667, saving model to /content/Niemeyer_Paper/2d_image_classification.h5
# 67/67 - 12s - loss: 2.1076 - accuracy: 0.3229 - val_loss: 2.0707 - val_accuracy: 0.3667 - 12s/epoch - 182ms/step
# Epoch 2/50
#
# Epoch 00002: val_accuracy did not improve from 0.36667
# 67/67 - 7s - loss: 2.0578 - accuracy: 0.3832 - val_loss: 1.9664 - val_accuracy: 0.3625 - 7s/epoch - 105ms/step
# Epoch 3/50
#
# Epoch 00003: val_accuracy improved from 0.36667 to 0.37083, saving model to /content/Niemeyer_Paper/2d_image_classification.h5
# 67/67 - 7s - loss: 2.0169 - accuracy: 0.3823 - val_loss: 1.9665 - val_accuracy: 0.3708 - 7s/epoch - 107ms/step
# Epoch 4/50
#
# Epoch 00004: val_accuracy did not improve from 0.37083
# 67/67 - 7s - loss: 1.9885 - accuracy: 0.3814 - val_loss: 1.9837 - val_accuracy: 0.3667 - 7s/epoch - 106ms/step
# Epoch 5/50
#
# Epoch 00005: val_accuracy did not improve from 0.37083
# 67/67 - 7s - loss: 1.9734 - accuracy: 0.3804 - val_loss: 1.9931 - val_accuracy: 0.3583 - 7s/epoch - 104ms/step
# Epoch 6/50
#
# Epoch 00006: val_accuracy did not improve from 0.37083
# 67/67 - 7s - loss: 1.9619 - accuracy: 0.3926 - val_loss: 1.9957 - val_accuracy: 0.3542 - 7s/epoch - 102ms/step
# Epoch 7/50
#
# Epoch 00007: val_accuracy did not improve from 0.37083
# 67/67 - 7s - loss: 1.9565 - accuracy: 0.3982 - val_loss: 1.9944 - val_accuracy: 0.3583 - 7s/epoch - 101ms/step
# Epoch 8/50
#
# Epoch 00008: val_accuracy improved from 0.37083 to 0.38333, saving model to /content/Niemeyer_Paper/2d_image_classification.h5
# 67/67 - 7s - loss: 1.9526 - accuracy: 0.3973 - val_loss: 1.9924 - val_accuracy: 0.3833 - 7s/epoch - 102ms/step
# Epoch 9/50
#
# Epoch 00009: val_accuracy did not improve from 0.38333
# 67/67 - 7s - loss: 1.9484 - accuracy: 0.4015 - val_loss: 1.9907 - val_accuracy: 0.3833 - 7s/epoch - 103ms/step
# Epoch 10/50
#
# Epoch 00010: val_accuracy did not improve from 0.38333
# 67/67 - 7s - loss: 1.9444 - accuracy: 0.4010 - val_loss: 1.9898 - val_accuracy: 0.3792 - 7s/epoch - 105ms/step
# Epoch 11/50
#
# Epoch 00011: val_accuracy improved from 0.38333 to 0.38750, saving model to /content/Niemeyer_Paper/2d_image_classification.h5
# 67/67 - 7s - loss: 1.9435 - accuracy: 0.4024 - val_loss: 1.9890 - val_accuracy: 0.3875 - 7s/epoch - 106ms/step
# Epoch 12/50
#
# Epoch 00012: val_accuracy did not improve from 0.38750
# 67/67 - 7s - loss: 1.9414 - accuracy: 0.4197 - val_loss: 1.9883 - val_accuracy: 0.3875 - 7s/epoch - 105ms/step
# Epoch 13/50
#
# Epoch 00013: val_accuracy did not improve from 0.38750
# 67/67 - 7s - loss: 1.9421 - accuracy: 0.3968 - val_loss: 1.9881 - val_accuracy: 0.3875 - 7s/epoch - 104ms/step
# Epoch 14/50
#
# Epoch 00014: val_accuracy did not improve from 0.38750
# 67/67 - 7s - loss: 1.9403 - accuracy: 0.4071 - val_loss: 1.9880 - val_accuracy: 0.3875 - 7s/epoch - 103ms/step
# Epoch 15/50
#
# Epoch 00015: val_accuracy did not improve from 0.38750
# 67/67 - 7s - loss: 1.9401 - accuracy: 0.4123 - val_loss: 1.9876 - val_accuracy: 0.3875 - 7s/epoch - 102ms/step
# Epoch 16/50
#
# Epoch 00016: val_accuracy did not improve from 0.38750
# 67/67 - 7s - loss: 1.9395 - accuracy: 0.4127 - val_loss: 1.9877 - val_accuracy: 0.3875 - 7s/epoch - 101ms/step
# Epoch 17/50
#
# Epoch 00017: val_accuracy did not improve from 0.38750
# 67/67 - 7s - loss: 1.9400 - accuracy: 0.4085 - val_loss: 1.9874 - val_accuracy: 0.3875 - 7s/epoch - 101ms/step
# Epoch 18/50
#
# Epoch 00018: val_accuracy did not improve from 0.38750
# 67/67 - 7s - loss: 1.9412 - accuracy: 0.3945 - val_loss: 1.9872 - val_accuracy: 0.3833 - 7s/epoch - 102ms/step
# Epoch 19/50
#
# Epoch 00019: val_accuracy improved from 0.38750 to 0.39167, saving model to /content/Niemeyer_Paper/2d_image_classification.h5
# 67/67 - 7s - loss: 1.9405 - accuracy: 0.4020 - val_loss: 1.9871 - val_accuracy: 0.3917 - 7s/epoch - 103ms/step
# Epoch 20/50
#
# Epoch 00020: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9386 - accuracy: 0.4024 - val_loss: 1.9865 - val_accuracy: 0.3917 - 7s/epoch - 103ms/step
# Epoch 21/50
#
# Epoch 00021: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9385 - accuracy: 0.4095 - val_loss: 1.9865 - val_accuracy: 0.3917 - 7s/epoch - 102ms/step
# Epoch 22/50
#
# Epoch 00022: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9394 - accuracy: 0.4066 - val_loss: 1.9866 - val_accuracy: 0.3917 - 7s/epoch - 103ms/step
# Epoch 23/50
#
# Epoch 00023: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9391 - accuracy: 0.4109 - val_loss: 1.9865 - val_accuracy: 0.3917 - 7s/epoch - 103ms/step
# Epoch 24/50
#
# Epoch 00024: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9385 - accuracy: 0.4006 - val_loss: 1.9865 - val_accuracy: 0.3917 - 7s/epoch - 103ms/step
# Epoch 25/50
#
# Epoch 00025: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9392 - accuracy: 0.4020 - val_loss: 1.9864 - val_accuracy: 0.3875 - 7s/epoch - 103ms/step
# Epoch 26/50
#
# Epoch 00026: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9388 - accuracy: 0.4160 - val_loss: 1.9866 - val_accuracy: 0.3917 - 7s/epoch - 102ms/step
# Epoch 27/50
#
# Epoch 00027: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9389 - accuracy: 0.4015 - val_loss: 1.9865 - val_accuracy: 0.3875 - 7s/epoch - 102ms/step
# Epoch 28/50
#
# Epoch 00028: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9380 - accuracy: 0.4174 - val_loss: 1.9864 - val_accuracy: 0.3917 - 7s/epoch - 103ms/step
# Epoch 29/50
#
# Epoch 00029: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9391 - accuracy: 0.4085 - val_loss: 1.9864 - val_accuracy: 0.3875 - 7s/epoch - 103ms/step
# Epoch 30/50
#
# Epoch 00030: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9389 - accuracy: 0.3935 - val_loss: 1.9863 - val_accuracy: 0.3833 - 7s/epoch - 103ms/step
# Epoch 31/50
#
# Epoch 00031: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9397 - accuracy: 0.3987 - val_loss: 1.9866 - val_accuracy: 0.3875 - 7s/epoch - 103ms/step
# Epoch 32/50
#
# Epoch 00032: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9394 - accuracy: 0.4165 - val_loss: 1.9866 - val_accuracy: 0.3833 - 7s/epoch - 104ms/step
# Epoch 33/50
#
# Epoch 00033: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9392 - accuracy: 0.4071 - val_loss: 1.9867 - val_accuracy: 0.3917 - 7s/epoch - 105ms/step
# Epoch 34/50
#
# Epoch 00034: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9386 - accuracy: 0.4062 - val_loss: 1.9867 - val_accuracy: 0.3833 - 7s/epoch - 104ms/step
# Epoch 35/50
#
# Epoch 00035: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9375 - accuracy: 0.4010 - val_loss: 1.9866 - val_accuracy: 0.3833 - 7s/epoch - 103ms/step
# Epoch 36/50
#
# Epoch 00036: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9386 - accuracy: 0.4024 - val_loss: 1.9867 - val_accuracy: 0.3833 - 7s/epoch - 102ms/step
# Epoch 37/50
#
# Epoch 00037: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9385 - accuracy: 0.4113 - val_loss: 1.9865 - val_accuracy: 0.3833 - 7s/epoch - 103ms/step
# Epoch 38/50
#
# Epoch 00038: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9385 - accuracy: 0.4066 - val_loss: 1.9865 - val_accuracy: 0.3833 - 7s/epoch - 103ms/step
# Epoch 39/50
#
# Epoch 00039: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9398 - accuracy: 0.4141 - val_loss: 1.9866 - val_accuracy: 0.3833 - 7s/epoch - 104ms/step
# Epoch 40/50
#
# Epoch 00040: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9379 - accuracy: 0.3954 - val_loss: 1.9865 - val_accuracy: 0.3833 - 7s/epoch - 104ms/step
# Epoch 41/50
#
# Epoch 00041: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9386 - accuracy: 0.4179 - val_loss: 1.9864 - val_accuracy: 0.3875 - 7s/epoch - 103ms/step
# Epoch 42/50
#
# Epoch 00042: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9386 - accuracy: 0.4118 - val_loss: 1.9864 - val_accuracy: 0.3833 - 7s/epoch - 103ms/step
# Epoch 43/50
#
# Epoch 00043: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9390 - accuracy: 0.4020 - val_loss: 1.9863 - val_accuracy: 0.3833 - 7s/epoch - 103ms/step
# Epoch 44/50
#
# Epoch 00044: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9388 - accuracy: 0.4020 - val_loss: 1.9864 - val_accuracy: 0.3875 - 7s/epoch - 103ms/step
# Epoch 45/50
#
# Epoch 00045: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9394 - accuracy: 0.4066 - val_loss: 1.9864 - val_accuracy: 0.3875 - 7s/epoch - 103ms/step
# Epoch 46/50
#
# Epoch 00046: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9396 - accuracy: 0.4043 - val_loss: 1.9865 - val_accuracy: 0.3833 - 7s/epoch - 103ms/step
# Epoch 47/50
#
# Epoch 00047: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9375 - accuracy: 0.4104 - val_loss: 1.9865 - val_accuracy: 0.3875 - 7s/epoch - 103ms/step
# Epoch 48/50
#
# Epoch 00048: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9384 - accuracy: 0.4010 - val_loss: 1.9864 - val_accuracy: 0.3875 - 7s/epoch - 103ms/step
# Epoch 49/50
#
# Epoch 00049: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9375 - accuracy: 0.4118 - val_loss: 1.9864 - val_accuracy: 0.3875 - 7s/epoch - 102ms/step
# Epoch 50/50
#
# Epoch 00050: val_accuracy did not improve from 0.39167
# 67/67 - 7s - loss: 1.9381 - accuracy: 0.4062 - val_loss: 1.9865 - val_accuracy: 0.3875 - 7s/epoch - 103ms/step

# %%
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
def get_model(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    # Image augmentation block
    x = data_augmentation(inputs)

    # Entry block
    x = layers.Conv2D(32, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.Conv2D(64, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    for size in [128, 256, 512, 728]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    x = layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.GlobalAveragePooling2D()(x)
    if num_classes == 2:
        activation = "sigmoid"
        units = 1
    else:
        activation = "softmax"
        units = num_classes

    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(units, activation=activation)(x)
    return keras.Model(inputs, outputs)

image_size=(64,64)
model = get_model(input_shape=image_size + (1,), num_classes=4)
# keras.utils.plot_model(model, show_shapes=True)
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-191f197223e4> in <module>()
#      50
#      51 image_size=(64,64)
# ---> 52 model = get_model(input_shape=image_size + (1,), num_classes=4)
#      53 # keras.utils.plot_model(model, show_shapes=True)
#      54 model.summary()
#
# <ipython-input-1-191f197223e4> in get_model(input_shape, num_classes)
#       1 def get_model(input_shape, num_classes):
# ----> 2     inputs = keras.Input(shape=input_shape)
#       3     # Image augmentation block
#       4     x = data_augmentation(inputs)
#       5
#
# NameError: name 'keras' is not defined

# %%
directory = "classification_from_scratch" # Save the entire model as a SavedModel.
parent_dir = os.getcwd() # Parent Directory path
path = os.path.join(parent_dir, directory) # Path
os.makedirs(path,exist_ok=True) # Create the directory
checkpoint_path = Path(os.path.join(path,"save_at_{epoch}.h5"))

epochs = 50

checkpoint_cb = keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                              monitor='val_accuracy',
                                              verbose=1,
                                              save_best_only=True,
                                              save_weights_only=True
                                              )

model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
history = model.fit(
    train_dataset, 
    epochs=epochs, 
    callbacks=[checkpoint_cb], 
    validation_data=validation_dataset,
)
# Out:
# Epoch 1/50
# 67/67 [==============================] - ETA: 0s - loss: 251.3151 - accuracy: 0.3472
# Epoch 00001: val_accuracy improved from -inf to 0.38750, saving model to /content/classification_from_scratch/save_at_1.h5
# 67/67 [==============================] - 6s 49ms/step - loss: 251.3151 - accuracy: 0.3472 - val_loss: 32.9747 - val_accuracy: 0.3875
# Epoch 2/50
# 67/67 [==============================] - ETA: 0s - loss: 11.6843 - accuracy: 0.3828
# Epoch 00002: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 30ms/step - loss: 11.6843 - accuracy: 0.3828 - val_loss: 3.9161 - val_accuracy: 0.3875
# Epoch 3/50
# 67/67 [==============================] - ETA: 0s - loss: 3.0619 - accuracy: 0.3875
# Epoch 00003: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 3.0619 - accuracy: 0.3875 - val_loss: 2.7897 - val_accuracy: 0.3875
# Epoch 4/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7972 - accuracy: 0.3832
# Epoch 00004: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7972 - accuracy: 0.3832 - val_loss: 2.7882 - val_accuracy: 0.3875
# Epoch 5/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7969 - accuracy: 0.3748
# Epoch 00005: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7969 - accuracy: 0.3748 - val_loss: 2.7935 - val_accuracy: 0.3875
# Epoch 6/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7957 - accuracy: 0.3762
# Epoch 00006: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7957 - accuracy: 0.3762 - val_loss: 2.8038 - val_accuracy: 0.3875
# Epoch 7/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7959 - accuracy: 0.3832
# Epoch 00007: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7959 - accuracy: 0.3832 - val_loss: 2.7934 - val_accuracy: 0.3875
# Epoch 8/50
# 65/67 [============================>.] - ETA: 0s - loss: 2.7950 - accuracy: 0.3731
# Epoch 00008: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7955 - accuracy: 0.3772 - val_loss: 2.7994 - val_accuracy: 0.3875
# Epoch 9/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7971 - accuracy: 0.3814
# Epoch 00009: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7971 - accuracy: 0.3814 - val_loss: 2.7937 - val_accuracy: 0.3875
# Epoch 10/50
# 65/67 [============================>.] - ETA: 0s - loss: 2.7973 - accuracy: 0.3880
# Epoch 00010: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7970 - accuracy: 0.3879 - val_loss: 2.7993 - val_accuracy: 0.3875
# Epoch 11/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7973 - accuracy: 0.3781
# Epoch 00011: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 30ms/step - loss: 2.7973 - accuracy: 0.3781 - val_loss: 2.7949 - val_accuracy: 0.3875
# Epoch 12/50
# 65/67 [============================>.] - ETA: 0s - loss: 2.7972 - accuracy: 0.3846
# Epoch 00012: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 30ms/step - loss: 2.7965 - accuracy: 0.3865 - val_loss: 2.7900 - val_accuracy: 0.3875
# Epoch 13/50
# 65/67 [============================>.] - ETA: 0s - loss: 2.7959 - accuracy: 0.3947
# Epoch 00013: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7958 - accuracy: 0.3940 - val_loss: 2.8057 - val_accuracy: 0.3875
# Epoch 14/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7965 - accuracy: 0.3917
# Epoch 00014: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7965 - accuracy: 0.3917 - val_loss: 2.7909 - val_accuracy: 0.3875
# Epoch 15/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7964 - accuracy: 0.3786
# Epoch 00015: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 30ms/step - loss: 2.7964 - accuracy: 0.3786 - val_loss: 2.7963 - val_accuracy: 0.3875
# Epoch 16/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7970 - accuracy: 0.3790
# Epoch 00016: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7970 - accuracy: 0.3790 - val_loss: 2.8037 - val_accuracy: 0.3875
# Epoch 17/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7958 - accuracy: 0.3865
# Epoch 00017: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7958 - accuracy: 0.3865 - val_loss: 2.7860 - val_accuracy: 0.3875
# Epoch 18/50
# 65/67 [============================>.] - ETA: 0s - loss: 2.7971 - accuracy: 0.3769
# Epoch 00018: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7965 - accuracy: 0.3781 - val_loss: 2.8124 - val_accuracy: 0.3875
# Epoch 19/50
# 65/67 [============================>.] - ETA: 0s - loss: 2.7971 - accuracy: 0.3885
# Epoch 00019: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7972 - accuracy: 0.3898 - val_loss: 2.7971 - val_accuracy: 0.3875
# Epoch 20/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7966 - accuracy: 0.3889
# Epoch 00020: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7966 - accuracy: 0.3889 - val_loss: 2.7963 - val_accuracy: 0.3875
# Epoch 21/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7959 - accuracy: 0.3823
# Epoch 00021: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7959 - accuracy: 0.3823 - val_loss: 2.7905 - val_accuracy: 0.3875
# Epoch 22/50
# 65/67 [============================>.] - ETA: 0s - loss: 2.7973 - accuracy: 0.3913
# Epoch 00022: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7972 - accuracy: 0.3907 - val_loss: 2.7919 - val_accuracy: 0.3875
# Epoch 23/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7967 - accuracy: 0.3720
# Epoch 00023: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7967 - accuracy: 0.3720 - val_loss: 2.8009 - val_accuracy: 0.3875
# Epoch 24/50
# 65/67 [============================>.] - ETA: 0s - loss: 2.7983 - accuracy: 0.3745
# Epoch 00024: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7978 - accuracy: 0.3739 - val_loss: 2.7935 - val_accuracy: 0.3875
# Epoch 25/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7963 - accuracy: 0.3865
# Epoch 00025: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7963 - accuracy: 0.3865 - val_loss: 2.8045 - val_accuracy: 0.3875
# Epoch 26/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7962 - accuracy: 0.3823
# Epoch 00026: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7962 - accuracy: 0.3823 - val_loss: 2.7939 - val_accuracy: 0.3875
# Epoch 27/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7960 - accuracy: 0.3795
# Epoch 00027: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7960 - accuracy: 0.3795 - val_loss: 2.7936 - val_accuracy: 0.3875
# Epoch 28/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7966 - accuracy: 0.3748
# Epoch 00028: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7966 - accuracy: 0.3748 - val_loss: 2.7877 - val_accuracy: 0.3875
# Epoch 29/50
# 65/67 [============================>.] - ETA: 0s - loss: 2.7967 - accuracy: 0.3870
# Epoch 00029: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7971 - accuracy: 0.3856 - val_loss: 2.7890 - val_accuracy: 0.3875
# Epoch 30/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7960 - accuracy: 0.3851
# Epoch 00030: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7960 - accuracy: 0.3851 - val_loss: 2.8032 - val_accuracy: 0.3875
# Epoch 31/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7970 - accuracy: 0.3758
# Epoch 00031: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7970 - accuracy: 0.3758 - val_loss: 2.8001 - val_accuracy: 0.3875
# Epoch 32/50
# 65/67 [============================>.] - ETA: 0s - loss: 2.7969 - accuracy: 0.3933
# Epoch 00032: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7970 - accuracy: 0.3926 - val_loss: 2.8011 - val_accuracy: 0.3875
# Epoch 33/50
# 65/67 [============================>.] - ETA: 0s - loss: 2.7961 - accuracy: 0.3861
# Epoch 00033: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7967 - accuracy: 0.3861 - val_loss: 2.7875 - val_accuracy: 0.3875
# Epoch 34/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7967 - accuracy: 0.3828
# Epoch 00034: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7967 - accuracy: 0.3828 - val_loss: 2.7945 - val_accuracy: 0.3875
# Epoch 35/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7962 - accuracy: 0.3847
# Epoch 00035: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7962 - accuracy: 0.3847 - val_loss: 2.7969 - val_accuracy: 0.3875
# Epoch 36/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7962 - accuracy: 0.3940
# Epoch 00036: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7962 - accuracy: 0.3940 - val_loss: 2.8038 - val_accuracy: 0.3875
# Epoch 37/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7972 - accuracy: 0.3926
# Epoch 00037: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7972 - accuracy: 0.3926 - val_loss: 2.8068 - val_accuracy: 0.3875
# Epoch 38/50
# 65/67 [============================>.] - ETA: 0s - loss: 2.7951 - accuracy: 0.3957
# Epoch 00038: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7957 - accuracy: 0.3964 - val_loss: 2.7921 - val_accuracy: 0.3875
# Epoch 39/50
# 65/67 [============================>.] - ETA: 0s - loss: 2.7973 - accuracy: 0.3745
# Epoch 00039: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7972 - accuracy: 0.3753 - val_loss: 2.8036 - val_accuracy: 0.3875
# Epoch 40/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7967 - accuracy: 0.3818
# Epoch 00040: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7967 - accuracy: 0.3818 - val_loss: 2.7920 - val_accuracy: 0.3875
# Epoch 41/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7970 - accuracy: 0.3814
# Epoch 00041: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7970 - accuracy: 0.3814 - val_loss: 2.7891 - val_accuracy: 0.3875
# Epoch 42/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7958 - accuracy: 0.3893
# Epoch 00042: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7958 - accuracy: 0.3893 - val_loss: 2.8093 - val_accuracy: 0.3875
# Epoch 43/50
# 65/67 [============================>.] - ETA: 0s - loss: 2.7962 - accuracy: 0.3832
# Epoch 00043: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7966 - accuracy: 0.3818 - val_loss: 2.7929 - val_accuracy: 0.3875
# Epoch 44/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7964 - accuracy: 0.3884
# Epoch 00044: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7964 - accuracy: 0.3884 - val_loss: 2.8030 - val_accuracy: 0.3875
# Epoch 45/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7969 - accuracy: 0.3786
# Epoch 00045: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7969 - accuracy: 0.3786 - val_loss: 2.8022 - val_accuracy: 0.3875
# Epoch 46/50
# 65/67 [============================>.] - ETA: 0s - loss: 2.7956 - accuracy: 0.3894
# Epoch 00046: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7963 - accuracy: 0.3884 - val_loss: 2.7844 - val_accuracy: 0.3875
# Epoch 47/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7970 - accuracy: 0.3804
# Epoch 00047: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7970 - accuracy: 0.3804 - val_loss: 2.7897 - val_accuracy: 0.3875
# Epoch 48/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7970 - accuracy: 0.3823
# Epoch 00048: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7970 - accuracy: 0.3823 - val_loss: 2.7983 - val_accuracy: 0.3875
# Epoch 49/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7961 - accuracy: 0.3893
# Epoch 00049: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7961 - accuracy: 0.3893 - val_loss: 2.7994 - val_accuracy: 0.3875
# Epoch 50/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7961 - accuracy: 0.3828
# Epoch 00050: val_accuracy did not improve from 0.38750
# 67/67 [==============================] - 2s 29ms/step - loss: 2.7961 - accuracy: 0.3828 - val_loss: 2.8010 - val_accuracy: 0.3875

# %%
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
