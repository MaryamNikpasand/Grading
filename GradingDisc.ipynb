# %% [markdown]
# <a href="https://colab.research.google.com/github/MaryamNikpasand/Grading/blob/main/GradingDisc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import tensorflow as tf
# !pip install -q -U keras-tuner
import keras_tuner as kt
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import layers
from pathlib import Path
from scipy import ndimage
from tensorflow.keras import regularizers
from tensorflow.keras import initializers
# Out:
#      |████████████████████████████████| 98 kB 4.2 MB/s

# %%
def read_files(filepath):
  """Read and load volume"""
  # Read file
  scan=plt.imread(filepath)
  # plt.imshow(scan, cmap = plt.cm.gray)
  # plt.show()
  # Get raw data
  return scan

# def normalize(volume):
#   """normalize the volume
#      The max value for normalization is: np.mean(max_all)+2*np.std(max_all)
#      The min value of all images in this dataset is 0
# """
#   min=0
#   max=1007.2348186941014
#   volume[volume<min]=min
#   volume[volume>max]=max
#   volume=(volume-min)/(max-min)
#   volume=volume.astype("float32")
#   return volume

# def normalize(volume):
#   """normalize the volume
#      Normalize with max and min of each image
# """
#   min=np.min(volume)
#   max=np.max(volume)
#   volume=(volume-min)/(max-min)
#   volume=volume.astype("float32")
#   return volume

def normalize(volume):
  """normalize the volume
     Normalize with mean and std of each image
"""
  Mean=np.mean(volume)
  Std=np.std(volume)
  volume=(volume-Mean)/Std
  volume=volume.astype("float32")
  return volume

def resize_volume(img):
  """Resize across z-axis"""
  # Set the desired depth
  desired_width = 64
  desired_height = 64
  # Get current depth
  current_width = img.shape[0]
  current_height = img.shape[-1]
  # Compute depth factor
  width = current_width / desired_width
  height = current_height / desired_height
  width_factor = 1 / width
  height_factor = 1 / height
  # Resize across z-axis
  img = ndimage.zoom(img, (width_factor, height_factor), order=1)
  # resize_and_rescale = tf.keras.Sequential([
  #   layers.experimental.preprocessing.Resizing(desired_width, desired_height, desired_depth)])
  # img = resize_and_rescale(tf.expand_dims(img, axis=-1))
  return img

def process_scan(path):
  """Read and resize volume"""
  # Read scan
  volume=read_files(path)
  # Normalize
  volume=normalize(volume)
  volume=resize_volume(volume)
  volume=tf.expand_dims(volume,axis=-1) #  Adding an extra dimension to the images to have them in (x,x,1) format 
  return volume

# %%
filepath = '/content/drive/MyDrive/PhD/Barocas/grading/LumbarDiscJointScoring_Main/ImageSelection/Discs/Takahashi/grade1/T2_TSE_SAG__0026_008.ima L4_L5.png'
scan = process_scan(filepath)
scan.shape
# Out:
# TensorShape([64, 64, 1])

# %%
# Folder "Disc" consist of MRI scans having Disc images,
Disc_paths = dict()
filepath_Disc='/content/drive/MyDrive/PhD/Barocas/grading/LumbarDiscJointScoring_Main/ImageSelection/Discs/Ladd'
for x in os.listdir(filepath_Disc):
    for y in os.listdir(os.path.join(filepath_Disc,x)):
        if x not in Disc_paths:
            Disc_paths[x] = [os.path.join(filepath_Disc, x, y)]
        else:
            Disc_paths[x].append(os.path.join(filepath_Disc, x, y))

print("Disc['grade1']:: " + str(len(Disc_paths['grade1'])))
print("Disc['grade2']:: " + str(len(Disc_paths['grade2'])))
print("Disc['grade3']:: " + str(len(Disc_paths['grade3'])))
print("Disc['grade4']:: " + str(len(Disc_paths['grade4'])))
print("Disc['grade5']:: " + str(len(Disc_paths['grade5'])))

# Read and process the scans.
Disc_grade1 = np.array([process_scan(path) for path in Disc_paths['grade1']])
Disc_grade2 = np.array([process_scan(path) for path in Disc_paths['grade2']])
Disc_grade3 = np.array([process_scan(path) for path in Disc_paths['grade3']])
Disc_grade4 = np.array([process_scan(path) for path in Disc_paths['grade4']])
Disc_grade5 = np.array([process_scan(path) for path in Disc_paths['grade5']])
# Out:
# Disc['grade1']:: 55
# Disc['grade2']:: 615
# Disc['grade3']:: 1002
# Disc['grade4']:: 876
# Disc['grade5']:: 85

# %%
# For the disc images assign 1-5
Disc_grade1_labels=np.array([[1, 0, 0, 0, 0] for _ in range(len(Disc_grade1))])
Disc_grade2_labels=np.array([[0, 1, 0, 0, 0] for _ in range(len(Disc_grade2))])
Disc_grade3_labels=np.array([[0, 0, 1, 0, 0] for _ in range(len(Disc_grade3))])
Disc_grade4_labels=np.array([[0, 0, 0, 1, 0] for _ in range(len(Disc_grade4))])
Disc_grade5_labels=np.array([[0, 0, 0, 0, 1] for _ in range(len(Disc_grade5))])

Disc_grade1_train_limit=int(len(Disc_paths['grade1'])*.8)
Disc_grade2_train_limit=int(len(Disc_paths['grade2'])*.8)
Disc_grade3_train_limit=int(len(Disc_paths['grade3'])*.8)
Disc_grade4_train_limit=int(len(Disc_paths['grade4'])*.8)
Disc_grade5_train_limit=int(len(Disc_paths['grade5'])*.8)

Disc_grade1_val_limit=int(len(Disc_paths['grade1'])*.1)+Disc_grade1_train_limit
Disc_grade2_val_limit=int(len(Disc_paths['grade2'])*.1)+Disc_grade2_train_limit
Disc_grade3_val_limit=int(len(Disc_paths['grade3'])*.1)+Disc_grade3_train_limit
Disc_grade4_val_limit=int(len(Disc_paths['grade4'])*.1)+Disc_grade4_train_limit
Disc_grade5_val_limit=int(len(Disc_paths['grade5'])*.1)+Disc_grade5_train_limit

# Split data in the ratio 70-30 for training and validation.
x_train=np.concatenate((Disc_grade1[:Disc_grade1_train_limit],
                        Disc_grade2[:Disc_grade2_train_limit],
                        Disc_grade3[:Disc_grade3_train_limit],
                        Disc_grade4[:Disc_grade4_train_limit],
                        Disc_grade5[:Disc_grade5_train_limit]),axis=0)

y_train=np.concatenate((Disc_grade1_labels[:Disc_grade1_train_limit],
                        Disc_grade2_labels[:Disc_grade2_train_limit],
                        Disc_grade3_labels[:Disc_grade3_train_limit],
                        Disc_grade4_labels[:Disc_grade4_train_limit],
                        Disc_grade5_labels[:Disc_grade5_train_limit]),axis=0)

x_val=np.concatenate((Disc_grade1[Disc_grade1_train_limit:Disc_grade1_val_limit],
                      Disc_grade2[Disc_grade2_train_limit:Disc_grade2_val_limit],
                      Disc_grade3[Disc_grade3_train_limit:Disc_grade3_val_limit],
                      Disc_grade4[Disc_grade4_train_limit:Disc_grade4_val_limit],
                      Disc_grade5[Disc_grade5_train_limit:Disc_grade5_val_limit]),axis=0)

y_val=np.concatenate((Disc_grade1_labels[Disc_grade1_train_limit:Disc_grade1_val_limit],
                      Disc_grade2_labels[Disc_grade2_train_limit:Disc_grade2_val_limit],
                      Disc_grade3_labels[Disc_grade3_train_limit:Disc_grade3_val_limit],
                      Disc_grade4_labels[Disc_grade4_train_limit:Disc_grade4_val_limit],
                      Disc_grade5_labels[Disc_grade5_train_limit:Disc_grade5_val_limit]),axis=0)

x_test=np.concatenate((Disc_grade1[Disc_grade1_val_limit:],
                       Disc_grade2[Disc_grade2_val_limit:],
                       Disc_grade3[Disc_grade3_val_limit:],
                       Disc_grade4[Disc_grade4_val_limit:],
                       Disc_grade5[Disc_grade5_val_limit:],),axis=0)

y_test=np.concatenate((Disc_grade1_labels[Disc_grade1_val_limit:],
                       Disc_grade2_labels[Disc_grade2_val_limit:],
                       Disc_grade3_labels[Disc_grade3_val_limit:],
                       Disc_grade4_labels[Disc_grade4_val_limit:],
                       Disc_grade5_labels[Disc_grade5_val_limit:]),axis=0)

print(
    "Number of samples in train, validation and test are %d, %d and %d."
    % (x_train.shape[0], x_val.shape[0],x_test.shape[0])
)

# Define data loaders
train_loader = tf.data.Dataset.from_tensor_slices((x_train, y_train ))
validation_loader = tf.data.Dataset.from_tensor_slices((x_val, y_val))
# Out:
# Number of samples in train, validation and test are 2105, 261 and 267.

# %%
AUTOTUNE = tf.data.AUTOTUNE
batch_size = 32
train_dataset = (
    train_loader.shuffle(len(x_train))
    .batch(batch_size)
    .prefetch(buffer_size=AUTOTUNE)
)

# Only rescale.
validation_dataset = (
    validation_loader.shuffle(len(x_val))
    .batch(batch_size)
    .prefetch(buffer_size=AUTOTUNE)
)

# # Visualize a set of images
# import matplotlib.pyplot as plt
# plt.figure(figsize=(10, 10))
# for images,labels in train_dataset.take(1):
#   for i in range(9):
#     ax=plt.subplot(3,3,i+1)
#     plt.imshow(np.squeeze(images[i].numpy()),cmap='gray')
#     plt.title(int(labels[i]))
#     plt.axis("off")

# Data augmentation
data_augmentation=keras.Sequential([
                                    layers.experimental.preprocessing.RandomFlip("horizontal"),
                                    layers.experimental.preprocessing.RandomRotation(.1)
])

# %%
def get_model_3D_CTscans(input_shape):
  """Build a 2D convolutional neural network model."""

  inputs = keras.Input(shape=input_shape)
  print(inputs.shape)
  # Image augmentation
  x=data_augmentation(inputs)

  x=layers.Conv2D(filters=64,kernel_size=3,strides=1,padding='valid', activation='relu',kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4))(x)
  x=layers.MaxPool2D(pool_size=2)(x)
  x=layers.BatchNormalization()(x)

  x=layers.Conv2D(filters=64,kernel_size=3,activation='relu',kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4))(x)
  x=layers.MaxPool2D(pool_size=2)(x)
  x=layers.BatchNormalization()(x)

  x=layers.Conv2D(filters=128,kernel_size=3,activation='relu',kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4))(x)
  x=layers.MaxPool2D(pool_size=2)(x)
  x=layers.BatchNormalization()(x)

  x=layers.Conv2D(filters=256,kernel_size=3,activation='relu',kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4))(x)
  x=layers.MaxPool2D(pool_size=2)(x)
  x=layers.BatchNormalization()(x)

  x=layers.GlobalAveragePooling2D()(x)
  x=layers.Dense(units=512,activation='relu', kernel_regularizer=regularizers.l2(.001))(x)
  x=layers.Dropout(.3)(x)

  outputs=layers.Dense(units=5,activation='softmax')(x)

  model=keras.Model(inputs,outputs,name='2dcnn')
  return model

image_size=(64,64)
model=get_model_3D_CTscans(input_shape=image_size + (1,))
model.summary()
# Out:
# (None, 64, 64, 1)
# Model: "2dcnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 1)]       0
#
#  sequential (Sequential)     (None, 64, 64, 1)         0
#
#  conv2d (Conv2D)             (None, 62, 62, 64)        640
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 64)       0
#  )
#
#  batch_normalization (BatchN  (None, 31, 31, 64)       256
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 14, 14, 64)       256
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 6, 6, 128)        512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 256)         295168
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 2, 2, 256)        1024
#  hNormalization)
#
#  global_average_pooling2d (G  (None, 256)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               131584
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 542,789
# Trainable params: 541,765
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
# %% Compile the model
initial_learning_rate=1e-4
lr_schedule=keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=initial_learning_rate,decay_steps=1e5,decay_rate=.96,staircase=True)

model.compile(
    loss="binary_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=lr_schedule),
    metrics=['accuracy'])

# Define callbacks
directory = "3D_CTscan" # Save the entire model as a SavedModel.
parent_dir = os.getcwd() # Parent Directory path
path = os.path.join(parent_dir, directory) # Path
os.makedirs(path,exist_ok=True) # Create the directory
checkpoint_path = Path(os.path.join(path,'2d_image_classification.h5'))
checkpoint_cb=keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,monitor='val_accuracy',save_best_only=True)

epochs=50
history=model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=epochs,
    shuffle=True,
    verbose=2,
    callbacks=[checkpoint_cb],
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-af9b9b5284da> in <module>()
#       2 initial_learning_rate=1e-4
#       3 # lr_schedule=keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=initial_learning_rate,decay_steps=1e5,decay_rate=.96,staircase=True)
# ----> 4 lr_schedule = hp.Float("lr", min_value=1e-4, max_value=1e-2, sampling="log")
#       5
#       6 model.compile(
#
# NameError: name 'hp' is not defined

# %%
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# %% Model
def get_model_Niemeyer_Paper(input_shape):
#   """Build a 2D convolutional neural network model."""

  inputs = keras.Input(shape=input_shape)
  # Image augmentation
  x=data_augmentation(inputs)

  x=layers.Conv2D(filters=32,kernel_size=3,strides=1,padding='same',
                  activation=layers.LeakyReLU(alpha=.01),
                  kernel_regularizer=regularizers.l2(5e-4),
                  kernel_initializer=initializers.HeNormal())(x)
  x=layers.BatchNormalization()(x)
  x=layers.Dropout(.2)(x)

  x=layers.Conv2D(filters=64,kernel_size=3,dilation_rate=2,strides=1,padding='same',
                  activation=layers.LeakyReLU(alpha=.01),
                  kernel_regularizer=regularizers.l2(5e-4),
                  kernel_initializer=initializers.HeNormal())(x)
  x=layers.BatchNormalization()(x)
  x=layers.Conv2D(filters=64,kernel_size=3,dilation_rate=2,strides=1,padding='same',
                  activation=layers.LeakyReLU(alpha=.01),
                  kernel_regularizer=regularizers.l2(5e-4),
                  kernel_initializer=initializers.HeNormal())(x)
  x=layers.BatchNormalization()(x)    
  x=layers.Dropout(.2)(x)
  x=layers.MaxPool2D(pool_size=2)(x)

  x=layers.Conv2D(filters=128,kernel_size=3,dilation_rate=2,strides=1,padding='same',
                  activation=layers.LeakyReLU(alpha=.01),
                  kernel_regularizer=regularizers.l2(5e-4),
                  kernel_initializer=initializers.HeNormal())(x)
  x=layers.BatchNormalization()(x)
  x=layers.Conv2D(filters=128,kernel_size=3,dilation_rate=2,strides=1,padding='same',
                  activation=layers.LeakyReLU(alpha=.01),
                  kernel_regularizer=regularizers.l2(5e-4),
                  kernel_initializer=initializers.HeNormal())(x)
  x=layers.BatchNormalization()(x)
  x=layers.Dropout(.2)(x)

  x=layers.Conv2D(filters=256,kernel_size=3,dilation_rate=3,strides=1,padding='same',
                  activation=layers.LeakyReLU(alpha=.01),
                  kernel_regularizer=regularizers.l2(5e-4),
                  kernel_initializer=initializers.HeNormal())(x)
  x=layers.BatchNormalization()(x)
  x=layers.Conv2D(filters=256,kernel_size=3,dilation_rate=3,strides=1,padding='same',
                  activation=layers.LeakyReLU(alpha=.01),
                  kernel_regularizer=regularizers.l2(5e-4),
                  kernel_initializer=initializers.HeNormal())(x)
  x=layers.BatchNormalization()(x)
  x=layers.Dropout(.2)(x)
  x=layers.MaxPool2D(pool_size=2)(x)

  x=layers.Conv2D(filters=512,kernel_size=3,strides=1,padding='valid',
                  activation=layers.LeakyReLU(alpha=.01),
                  kernel_regularizer=regularizers.l2(5e-4),
                  kernel_initializer=initializers.HeNormal())(x)
  x=layers.BatchNormalization()(x)
  x=layers.Dropout(.2)(x)

  x=layers.GlobalAveragePooling2D()(x)
  x=layers.Dense(units=512,activation='relu')(x)

  outputs=layers.Dense(units=5,activation='softmax')(x) #change this to softmax when working wiht gradings

  model=keras.Model(inputs,outputs,name='2dcnn')
  return model

image_size=(64,64)
model=get_model_Niemeyer_Paper(input_shape=image_size + (1,))
model.summary()
# Out:
# Model: "2dcnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 64, 64, 1)]       0
#
#  sequential (Sequential)     (None, 64, 64, 1)         0
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 32)        320
#
#  batch_normalization_4 (Batc  (None, 64, 64, 32)       128
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 64, 64, 32)        0
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 64)        18496
#
#  batch_normalization_5 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 64, 64, 64)        36928
#
#  batch_normalization_6 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 64, 64, 64)        0
#
#  max_pooling2d_4 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 128)       73856
#
#  batch_normalization_7 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 128)       147584
#
#  batch_normalization_8 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 32, 32, 128)       0
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 256)       295168
#
#  batch_normalization_9 (Batc  (None, 32, 32, 256)      1024
#  hNormalization)
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 256)       590080
#
#  batch_normalization_10 (Bat  (None, 32, 32, 256)      1024
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 32, 32, 256)       0
#
#  max_pooling2d_5 (MaxPooling  (None, 16, 16, 256)      0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 14, 14, 512)       1180160
#
#  batch_normalization_11 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 14, 14, 512)       0
#
#  global_average_pooling2d_1   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dense_3 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 2,613,573
# Trainable params: 2,610,693
# Non-trainable params: 2,880
# _________________________________________________________________

# %%
# %% Compile the model
epochs=50
initial_learning_rate=1e-3
num_steps=np.floor(len(x_train)/batch_size)
boundaries=[]
values=[initial_learning_rate]
indx=1
while indx<int(epochs/10):
    boundaries.append(indx*10*num_steps)
    values.append(initial_learning_rate/(10**(indx)))
    indx+=1

# lr_schedule = keras.optimizers.schedules.PiecewiseConstantDecay(boundaries,values)
lr_schedule=keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=initial_learning_rate,decay_steps=1e5,decay_rate=.96,staircase=True)

model.compile(
    # loss=tf.keras.losses.CategoricalCrossentropy(),
    loss="binary_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=lr_schedule),
    metrics=['accuracy'])

# Define callbacks
directory = "Niemeyer_Paper" # Save the entire model as a SavedModel.
parent_dir = os.getcwd() # Parent Directory path
path = os.path.join(parent_dir, directory) # Path
os.makedirs(path,exist_ok=True) # Create the directory
checkpoint_path = Path(os.path.join(path,'2d_image_classification.h5'))
checkpoint_cb=keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                              monitor='val_accuracy',
                                              verbose=1,
                                              save_best_only=True,
                                              save_weights_only=True
                                              )


history=model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=epochs,
    shuffle=True,
    verbose=2,
    callbacks=[checkpoint_cb],
)
# Out:
# Epoch 1/50
#
# Epoch 00001: val_accuracy improved from -inf to 0.65517, saving model to /content/Niemeyer_Paper/2d_image_classification.h5
# 66/66 - 9s - loss: 1.4421 - accuracy: 0.5981 - val_loss: 1.2364 - val_accuracy: 0.6552 - 9s/epoch - 132ms/step
# Epoch 2/50
#
# Epoch 00002: val_accuracy did not improve from 0.65517
# 66/66 - 7s - loss: 0.9520 - accuracy: 0.6527 - val_loss: 0.8267 - val_accuracy: 0.6475 - 7s/epoch - 101ms/step
# Epoch 3/50
#
# Epoch 00003: val_accuracy improved from 0.65517 to 0.69732, saving model to /content/Niemeyer_Paper/2d_image_classification.h5
# 66/66 - 7s - loss: 0.6948 - accuracy: 0.6627 - val_loss: 0.6081 - val_accuracy: 0.6973 - 7s/epoch - 104ms/step
# Epoch 4/50
#
# Epoch 00004: val_accuracy did not improve from 0.69732
# 66/66 - 7s - loss: 0.5568 - accuracy: 0.6746 - val_loss: 0.5320 - val_accuracy: 0.6245 - 7s/epoch - 106ms/step
# Epoch 5/50
#
# Epoch 00005: val_accuracy did not improve from 0.69732
# 66/66 - 7s - loss: 0.4938 - accuracy: 0.6675 - val_loss: 0.6240 - val_accuracy: 0.5287 - 7s/epoch - 106ms/step
# Epoch 6/50
#
# Epoch 00006: val_accuracy improved from 0.69732 to 0.72031, saving model to /content/Niemeyer_Paper/2d_image_classification.h5
# 66/66 - 7s - loss: 0.4453 - accuracy: 0.6931 - val_loss: 0.4698 - val_accuracy: 0.7203 - 7s/epoch - 106ms/step
# Epoch 7/50
#
# Epoch 00007: val_accuracy did not improve from 0.72031
# 66/66 - 7s - loss: 0.4188 - accuracy: 0.6950 - val_loss: 0.4888 - val_accuracy: 0.5364 - 7s/epoch - 104ms/step
# Epoch 8/50
#
# Epoch 00008: val_accuracy did not improve from 0.72031
# 66/66 - 7s - loss: 0.3969 - accuracy: 0.6893 - val_loss: 0.4522 - val_accuracy: 0.5441 - 7s/epoch - 102ms/step
# Epoch 9/50
#
# Epoch 00009: val_accuracy did not improve from 0.72031
# 66/66 - 7s - loss: 0.3786 - accuracy: 0.6998 - val_loss: 0.5645 - val_accuracy: 0.4406 - 7s/epoch - 102ms/step
# Epoch 10/50
#
# Epoch 00010: val_accuracy did not improve from 0.72031
# 66/66 - 7s - loss: 0.3705 - accuracy: 0.6974 - val_loss: 0.4908 - val_accuracy: 0.5364 - 7s/epoch - 102ms/step
# Epoch 11/50
#
# Epoch 00011: val_accuracy improved from 0.72031 to 0.72797, saving model to /content/Niemeyer_Paper/2d_image_classification.h5
# 66/66 - 7s - loss: 0.3685 - accuracy: 0.6898 - val_loss: 0.3587 - val_accuracy: 0.7280 - 7s/epoch - 103ms/step
# Epoch 12/50
#
# Epoch 00012: val_accuracy did not improve from 0.72797
# 66/66 - 7s - loss: 0.3523 - accuracy: 0.6979 - val_loss: 0.4965 - val_accuracy: 0.4521 - 7s/epoch - 104ms/step
# Epoch 13/50
#
# Epoch 00013: val_accuracy did not improve from 0.72797
# 66/66 - 7s - loss: 0.3425 - accuracy: 0.7007 - val_loss: 0.3838 - val_accuracy: 0.6207 - 7s/epoch - 105ms/step
# Epoch 14/50
#
# Epoch 00014: val_accuracy did not improve from 0.72797
# 66/66 - 7s - loss: 0.3466 - accuracy: 0.6874 - val_loss: 0.5042 - val_accuracy: 0.4291 - 7s/epoch - 104ms/step
# Epoch 15/50
#
# Epoch 00015: val_accuracy did not improve from 0.72797
# 66/66 - 7s - loss: 0.3368 - accuracy: 0.7050 - val_loss: 0.4688 - val_accuracy: 0.5632 - 7s/epoch - 103ms/step
# Epoch 16/50
#
# Epoch 00016: val_accuracy did not improve from 0.72797
# 66/66 - 7s - loss: 0.3414 - accuracy: 0.6893 - val_loss: 0.3234 - val_accuracy: 0.7165 - 7s/epoch - 102ms/step
# Epoch 17/50
#
# Epoch 00017: val_accuracy did not improve from 0.72797
# 66/66 - 7s - loss: 0.3287 - accuracy: 0.7064 - val_loss: 0.3873 - val_accuracy: 0.7126 - 7s/epoch - 102ms/step
# Epoch 18/50
#
# Epoch 00018: val_accuracy did not improve from 0.72797
# 66/66 - 7s - loss: 0.3225 - accuracy: 0.7164 - val_loss: 0.3516 - val_accuracy: 0.6552 - 7s/epoch - 102ms/step
# Epoch 19/50
#
# Epoch 00019: val_accuracy did not improve from 0.72797
# 66/66 - 7s - loss: 0.3235 - accuracy: 0.7107 - val_loss: 0.3828 - val_accuracy: 0.6475 - 7s/epoch - 102ms/step
# Epoch 20/50
#
# Epoch 00020: val_accuracy did not improve from 0.72797
# 66/66 - 7s - loss: 0.3194 - accuracy: 0.7216 - val_loss: 0.3506 - val_accuracy: 0.6667 - 7s/epoch - 103ms/step
# Epoch 21/50
#
# Epoch 00021: val_accuracy did not improve from 0.72797
# 66/66 - 7s - loss: 0.3204 - accuracy: 0.7045 - val_loss: 0.3538 - val_accuracy: 0.6169 - 7s/epoch - 103ms/step
# Epoch 22/50
#
# Epoch 00022: val_accuracy did not improve from 0.72797
# 66/66 - 7s - loss: 0.3202 - accuracy: 0.7093 - val_loss: 0.3736 - val_accuracy: 0.6513 - 7s/epoch - 104ms/step
# Epoch 23/50
#
# Epoch 00023: val_accuracy did not improve from 0.72797
# 66/66 - 7s - loss: 0.3068 - accuracy: 0.7264 - val_loss: 0.3337 - val_accuracy: 0.6858 - 7s/epoch - 103ms/step
# Epoch 24/50
#
# Epoch 00024: val_accuracy did not improve from 0.72797
# 66/66 - 7s - loss: 0.3065 - accuracy: 0.7197 - val_loss: 0.3255 - val_accuracy: 0.7241 - 7s/epoch - 103ms/step
# Epoch 25/50
#
# Epoch 00025: val_accuracy did not improve from 0.72797
# 66/66 - 7s - loss: 0.3040 - accuracy: 0.7292 - val_loss: 0.4030 - val_accuracy: 0.6245 - 7s/epoch - 103ms/step
# Epoch 26/50
#
# Epoch 00026: val_accuracy did not improve from 0.72797
# 66/66 - 7s - loss: 0.3071 - accuracy: 0.7192 - val_loss: 0.3410 - val_accuracy: 0.6897 - 7s/epoch - 102ms/step
# Epoch 27/50
#
# Epoch 00027: val_accuracy did not improve from 0.72797
# 66/66 - 7s - loss: 0.3066 - accuracy: 0.7207 - val_loss: 0.3688 - val_accuracy: 0.6054 - 7s/epoch - 102ms/step
# Epoch 28/50
#
# Epoch 00028: val_accuracy did not improve from 0.72797
# 66/66 - 7s - loss: 0.3036 - accuracy: 0.7264 - val_loss: 0.3179 - val_accuracy: 0.7088 - 7s/epoch - 103ms/step
# Epoch 29/50
#
# Epoch 00029: val_accuracy did not improve from 0.72797
# 66/66 - 7s - loss: 0.2995 - accuracy: 0.7230 - val_loss: 0.3386 - val_accuracy: 0.6973 - 7s/epoch - 103ms/step
# Epoch 30/50
#
# Epoch 00030: val_accuracy did not improve from 0.72797
# 66/66 - 7s - loss: 0.3076 - accuracy: 0.7226 - val_loss: 0.3208 - val_accuracy: 0.6973 - 7s/epoch - 102ms/step
# Epoch 31/50
#
# Epoch 00031: val_accuracy did not improve from 0.72797
# 66/66 - 7s - loss: 0.3074 - accuracy: 0.7164 - val_loss: 0.3492 - val_accuracy: 0.6897 - 7s/epoch - 103ms/step
# Epoch 32/50
#
# Epoch 00032: val_accuracy improved from 0.72797 to 0.75862, saving model to /content/Niemeyer_Paper/2d_image_classification.h5
# 66/66 - 7s - loss: 0.3002 - accuracy: 0.7230 - val_loss: 0.3105 - val_accuracy: 0.7586 - 7s/epoch - 104ms/step
# Epoch 33/50
#
# Epoch 00033: val_accuracy did not improve from 0.75862
# 66/66 - 7s - loss: 0.2946 - accuracy: 0.7368 - val_loss: 0.4542 - val_accuracy: 0.5517 - 7s/epoch - 102ms/step
# Epoch 34/50
#
# Epoch 00034: val_accuracy did not improve from 0.75862
# 66/66 - 7s - loss: 0.2911 - accuracy: 0.7397 - val_loss: 0.3392 - val_accuracy: 0.6897 - 7s/epoch - 103ms/step
# Epoch 35/50
#
# Epoch 00035: val_accuracy did not improve from 0.75862
# 66/66 - 7s - loss: 0.2969 - accuracy: 0.7264 - val_loss: 0.3696 - val_accuracy: 0.6398 - 7s/epoch - 103ms/step
# Epoch 36/50
#
# Epoch 00036: val_accuracy did not improve from 0.75862
# 66/66 - 7s - loss: 0.3018 - accuracy: 0.7306 - val_loss: 0.4056 - val_accuracy: 0.6475 - 7s/epoch - 102ms/step
# Epoch 37/50
#
# Epoch 00037: val_accuracy did not improve from 0.75862
# 66/66 - 7s - loss: 0.2987 - accuracy: 0.7273 - val_loss: 0.3432 - val_accuracy: 0.7165 - 7s/epoch - 102ms/step
# Epoch 38/50
#
# Epoch 00038: val_accuracy did not improve from 0.75862
# 66/66 - 7s - loss: 0.2943 - accuracy: 0.7330 - val_loss: 0.3331 - val_accuracy: 0.7050 - 7s/epoch - 102ms/step
# Epoch 39/50
#
# Epoch 00039: val_accuracy did not improve from 0.75862
# 66/66 - 7s - loss: 0.2878 - accuracy: 0.7401 - val_loss: 0.3346 - val_accuracy: 0.7280 - 7s/epoch - 103ms/step
# Epoch 40/50
#
# Epoch 00040: val_accuracy did not improve from 0.75862
# 66/66 - 7s - loss: 0.2909 - accuracy: 0.7335 - val_loss: 0.3639 - val_accuracy: 0.6973 - 7s/epoch - 104ms/step
# Epoch 41/50
#
# Epoch 00041: val_accuracy did not improve from 0.75862
# 66/66 - 7s - loss: 0.2959 - accuracy: 0.7306 - val_loss: 0.5342 - val_accuracy: 0.4751 - 7s/epoch - 103ms/step
# Epoch 42/50
#
# Epoch 00042: val_accuracy did not improve from 0.75862
# 66/66 - 7s - loss: 0.2859 - accuracy: 0.7435 - val_loss: 0.3417 - val_accuracy: 0.6858 - 7s/epoch - 102ms/step
# Epoch 43/50
#
# Epoch 00043: val_accuracy did not improve from 0.75862
# 66/66 - 7s - loss: 0.2896 - accuracy: 0.7273 - val_loss: 0.3309 - val_accuracy: 0.6935 - 7s/epoch - 102ms/step
# Epoch 44/50
#
# Epoch 00044: val_accuracy did not improve from 0.75862
# 66/66 - 7s - loss: 0.2862 - accuracy: 0.7378 - val_loss: 0.3474 - val_accuracy: 0.6897 - 7s/epoch - 102ms/step
# Epoch 45/50
#
# Epoch 00045: val_accuracy did not improve from 0.75862
# 66/66 - 7s - loss: 0.2862 - accuracy: 0.7382 - val_loss: 0.3365 - val_accuracy: 0.6897 - 7s/epoch - 102ms/step
# Epoch 46/50
#
# Epoch 00046: val_accuracy did not improve from 0.75862
# 66/66 - 7s - loss: 0.2948 - accuracy: 0.7254 - val_loss: 0.3561 - val_accuracy: 0.6667 - 7s/epoch - 102ms/step
# Epoch 47/50
#
# Epoch 00047: val_accuracy did not improve from 0.75862
# 66/66 - 7s - loss: 0.2933 - accuracy: 0.7302 - val_loss: 0.4655 - val_accuracy: 0.5862 - 7s/epoch - 103ms/step
# Epoch 48/50
#
# Epoch 00048: val_accuracy did not improve from 0.75862
# 66/66 - 7s - loss: 0.2804 - accuracy: 0.7397 - val_loss: 0.3471 - val_accuracy: 0.6628 - 7s/epoch - 103ms/step
# Epoch 49/50
#
# Epoch 00049: val_accuracy did not improve from 0.75862
# 66/66 - 7s - loss: 0.2847 - accuracy: 0.7378 - val_loss: 0.3032 - val_accuracy: 0.7318 - 7s/epoch - 103ms/step
# Epoch 50/50
#
# Epoch 00050: val_accuracy did not improve from 0.75862
# 66/66 - 7s - loss: 0.2846 - accuracy: 0.7287 - val_loss: 0.3513 - val_accuracy: 0.6667 - 7s/epoch - 103ms/step

# %%
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
def get_model(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    # Image augmentation block
    x = data_augmentation(inputs)

    # Entry block
    x = layers.Conv2D(32, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.Conv2D(64, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    for size in [128, 256, 512, 728]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    x = layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.GlobalAveragePooling2D()(x)
    if num_classes == 2:
        activation = "sigmoid"
        units = 1
    else:
        activation = "softmax"
        units = num_classes

    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(units, activation=activation)(x)
    return keras.Model(inputs, outputs)

image_size=(64,64)
model = get_model(input_shape=image_size + (1,), num_classes=5)
# keras.utils.plot_model(model, show_shapes=True)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  sequential (Sequential)        (None, 64, 64, 1)    0           ['input_3[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 32)   320         ['sequential[2][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 32)  128         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation (Activation)        (None, 32, 32, 32)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 64)   18496       ['activation[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 64)  256         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_1 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_13[0][0]']
#
#  activation_2 (Activation)      (None, 32, 32, 64)   0           ['activation_1[0][0]']
#
#  separable_conv2d (SeparableCon  (None, 32, 32, 128)  8896       ['activation_2[0][0]']
#  v2D)
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 128)  512        ['separable_conv2d[0][0]']
#  ormalization)
#
#  activation_3 (Activation)      (None, 32, 32, 128)  0           ['batch_normalization_14[0][0]']
#
#  separable_conv2d_1 (SeparableC  (None, 32, 32, 128)  17664      ['activation_3[0][0]']
#  onv2D)
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 128)  512        ['separable_conv2d_1[0][0]']
#  ormalization)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 16, 16, 128)  0          ['batch_normalization_15[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 16, 16, 128)  8320        ['activation_1[0][0]']
#
#  add (Add)                      (None, 16, 16, 128)  0           ['max_pooling2d_6[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  activation_4 (Activation)      (None, 16, 16, 128)  0           ['add[0][0]']
#
#  separable_conv2d_2 (SeparableC  (None, 16, 16, 256)  34176      ['activation_4[0][0]']
#  onv2D)
#
#  batch_normalization_16 (BatchN  (None, 16, 16, 256)  1024       ['separable_conv2d_2[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 16, 16, 256)  0           ['batch_normalization_16[0][0]']
#
#  separable_conv2d_3 (SeparableC  (None, 16, 16, 256)  68096      ['activation_5[0][0]']
#  onv2D)
#
#  batch_normalization_17 (BatchN  (None, 16, 16, 256)  1024       ['separable_conv2d_3[0][0]']
#  ormalization)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 8, 8, 256)   0           ['batch_normalization_17[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 8, 8, 256)    33024       ['add[0][0]']
#
#  add_1 (Add)                    (None, 8, 8, 256)    0           ['max_pooling2d_7[0][0]',
#                                                                   'conv2d_15[0][0]']
#
#  activation_6 (Activation)      (None, 8, 8, 256)    0           ['add_1[0][0]']
#
#  separable_conv2d_4 (SeparableC  (None, 8, 8, 512)   133888      ['activation_6[0][0]']
#  onv2D)
#
#  batch_normalization_18 (BatchN  (None, 8, 8, 512)   2048        ['separable_conv2d_4[0][0]']
#  ormalization)
#
#  activation_7 (Activation)      (None, 8, 8, 512)    0           ['batch_normalization_18[0][0]']
#
#  separable_conv2d_5 (SeparableC  (None, 8, 8, 512)   267264      ['activation_7[0][0]']
#  onv2D)
#
#  batch_normalization_19 (BatchN  (None, 8, 8, 512)   2048        ['separable_conv2d_5[0][0]']
#  ormalization)
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 4, 4, 512)   0           ['batch_normalization_19[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 4, 4, 512)    131584      ['add_1[0][0]']
#
#  add_2 (Add)                    (None, 4, 4, 512)    0           ['max_pooling2d_8[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  activation_8 (Activation)      (None, 4, 4, 512)    0           ['add_2[0][0]']
#
#  separable_conv2d_6 (SeparableC  (None, 4, 4, 728)   378072      ['activation_8[0][0]']
#  onv2D)
#
#  batch_normalization_20 (BatchN  (None, 4, 4, 728)   2912        ['separable_conv2d_6[0][0]']
#  ormalization)
#
#  activation_9 (Activation)      (None, 4, 4, 728)    0           ['batch_normalization_20[0][0]']
#
#  separable_conv2d_7 (SeparableC  (None, 4, 4, 728)   537264      ['activation_9[0][0]']
#  onv2D)
#
#  batch_normalization_21 (BatchN  (None, 4, 4, 728)   2912        ['separable_conv2d_7[0][0]']
#  ormalization)
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 2, 2, 728)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 2, 2, 728)    373464      ['add_2[0][0]']
#
#  add_3 (Add)                    (None, 2, 2, 728)    0           ['max_pooling2d_9[0][0]',
#                                                                   'conv2d_17[0][0]']
#
#  separable_conv2d_8 (SeparableC  (None, 2, 2, 1024)  753048      ['add_3[0][0]']
#  onv2D)
#
#  batch_normalization_22 (BatchN  (None, 2, 2, 1024)  4096        ['separable_conv2d_8[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 2, 2, 1024)   0           ['batch_normalization_22[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 1024)        0           ['activation_10[0][0]']
#  obalAveragePooling2D)
#
#  dropout_6 (Dropout)            (None, 1024)         0           ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  dense_4 (Dense)                (None, 5)            5125        ['dropout_6[0][0]']
#
# ==================================================================================================
# Total params: 2,786,173
# Trainable params: 2,777,437
# Non-trainable params: 8,736
# __________________________________________________________________________________________________

# %%
directory = "classification_from_scratch" # Save the entire model as a SavedModel.
parent_dir = os.getcwd() # Parent Directory path
path = os.path.join(parent_dir, directory) # Path
os.makedirs(path,exist_ok=True) # Create the directory
checkpoint_path = Path(os.path.join(path,"save_at_{epoch}.h5"))
initial_learning_rate=1e-3

lr_schedule=keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=initial_learning_rate,decay_steps=1e5,decay_rate=.96,staircase=True)

epochs = 50

checkpoint_cb = keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                              monitor='val_accuracy',
                                              verbose=1,
                                              save_best_only=True,
                                              save_weights_only=True
                                              )

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=lr_schedule),
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
history = model.fit(
    train_dataset, 
    epochs=epochs, 
    callbacks=[checkpoint_cb], 
    validation_data=validation_dataset,
)
# Out:
# Epoch 1/50
# 66/66 [==============================] - ETA: 0s - loss: 3.4440 - accuracy: 0.6827
# Epoch 00001: val_accuracy improved from -inf to 0.33333, saving model to /content/classification_from_scratch/save_at_1.h5
# 66/66 [==============================] - 5s 38ms/step - loss: 3.4440 - accuracy: 0.6827 - val_loss: 2.5508 - val_accuracy: 0.3333
# Epoch 2/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3239 - accuracy: 0.6678
# Epoch 00002: val_accuracy improved from 0.33333 to 0.38314, saving model to /content/classification_from_scratch/save_at_2.h5
# 66/66 [==============================] - 2s 32ms/step - loss: 2.3253 - accuracy: 0.6651 - val_loss: 2.2720 - val_accuracy: 0.3831
# Epoch 3/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3016 - accuracy: 0.6687
# Epoch 00003: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.3024 - accuracy: 0.6708 - val_loss: 2.7859 - val_accuracy: 0.3831
# Epoch 4/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3048 - accuracy: 0.6769
# Epoch 00004: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 31ms/step - loss: 2.3017 - accuracy: 0.6755 - val_loss: 2.6962 - val_accuracy: 0.2337
# Epoch 5/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3282 - accuracy: 0.6779
# Epoch 00005: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.3316 - accuracy: 0.6770 - val_loss: 5.1721 - val_accuracy: 0.2337
# Epoch 6/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.2927 - accuracy: 0.6774
# Epoch 00006: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.2911 - accuracy: 0.6760 - val_loss: 16.3531 - val_accuracy: 0.2337
# Epoch 7/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3098 - accuracy: 0.6812
# Epoch 00007: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.3098 - accuracy: 0.6793 - val_loss: 13.8406 - val_accuracy: 0.2337
# Epoch 8/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3251 - accuracy: 0.6894
# Epoch 00008: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.3240 - accuracy: 0.6879 - val_loss: 20.4580 - val_accuracy: 0.2337
# Epoch 9/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.2961 - accuracy: 0.6861
# Epoch 00009: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.2955 - accuracy: 0.6865 - val_loss: 17.2493 - val_accuracy: 0.2337
# Epoch 10/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3097 - accuracy: 0.6606
# Epoch 00010: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.3056 - accuracy: 0.6603 - val_loss: 2.9905 - val_accuracy: 0.3333
# Epoch 11/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3315 - accuracy: 0.6803
# Epoch 00011: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 31ms/step - loss: 2.3352 - accuracy: 0.6798 - val_loss: 7.4005 - val_accuracy: 0.2337
# Epoch 12/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.2929 - accuracy: 0.6731
# Epoch 00012: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 31ms/step - loss: 2.2904 - accuracy: 0.6713 - val_loss: 9.5571 - val_accuracy: 0.2337
# Epoch 13/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3126 - accuracy: 0.6851
# Epoch 00013: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.3101 - accuracy: 0.6860 - val_loss: 2.5530 - val_accuracy: 0.2337
# Epoch 14/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3268 - accuracy: 0.6846
# Epoch 00014: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.3259 - accuracy: 0.6850 - val_loss: 4.3649 - val_accuracy: 0.2337
# Epoch 15/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3020 - accuracy: 0.6731
# Epoch 00015: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.2994 - accuracy: 0.6746 - val_loss: 3.0188 - val_accuracy: 0.2337
# Epoch 16/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.2978 - accuracy: 0.7077
# Epoch 00016: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.2948 - accuracy: 0.7069 - val_loss: 2.6732 - val_accuracy: 0.3333
# Epoch 17/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3348 - accuracy: 0.7010
# Epoch 00017: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 31ms/step - loss: 2.3396 - accuracy: 0.6979 - val_loss: 14.3240 - val_accuracy: 0.2337
# Epoch 18/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.2777 - accuracy: 0.6726
# Epoch 00018: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 31ms/step - loss: 2.2765 - accuracy: 0.6717 - val_loss: 3.1083 - val_accuracy: 0.3333
# Epoch 19/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3057 - accuracy: 0.6942
# Epoch 00019: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.3039 - accuracy: 0.6945 - val_loss: 3.5477 - val_accuracy: 0.2337
# Epoch 20/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3340 - accuracy: 0.6846
# Epoch 00020: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 31ms/step - loss: 2.3332 - accuracy: 0.6836 - val_loss: 10.0408 - val_accuracy: 0.2337
# Epoch 21/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.2922 - accuracy: 0.6851
# Epoch 00021: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.2914 - accuracy: 0.6850 - val_loss: 14.8847 - val_accuracy: 0.2337
# Epoch 22/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3107 - accuracy: 0.6827
# Epoch 00022: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.3103 - accuracy: 0.6803 - val_loss: 21.3614 - val_accuracy: 0.2337
# Epoch 23/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3320 - accuracy: 0.6750
# Epoch 00023: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.3339 - accuracy: 0.6746 - val_loss: 6.8858 - val_accuracy: 0.2337
# Epoch 24/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.2737 - accuracy: 0.6769
# Epoch 00024: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 31ms/step - loss: 2.2715 - accuracy: 0.6755 - val_loss: 2.9059 - val_accuracy: 0.3333
# Epoch 25/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3131 - accuracy: 0.6837
# Epoch 00025: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 31ms/step - loss: 2.3114 - accuracy: 0.6846 - val_loss: 2.4605 - val_accuracy: 0.3831
# Epoch 26/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3269 - accuracy: 0.6817
# Epoch 00026: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 31ms/step - loss: 2.3260 - accuracy: 0.6817 - val_loss: 3.5093 - val_accuracy: 0.2337
# Epoch 27/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.2926 - accuracy: 0.6909
# Epoch 00027: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.2909 - accuracy: 0.6917 - val_loss: 15.4500 - val_accuracy: 0.2337
# Epoch 28/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3113 - accuracy: 0.6822
# Epoch 00028: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.3073 - accuracy: 0.6831 - val_loss: 28.4371 - val_accuracy: 0.2337
# Epoch 29/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3307 - accuracy: 0.6793
# Epoch 00029: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.3308 - accuracy: 0.6808 - val_loss: 20.6626 - val_accuracy: 0.2337
# Epoch 30/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.2798 - accuracy: 0.6827
# Epoch 00030: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.2767 - accuracy: 0.6817 - val_loss: 8.4086 - val_accuracy: 0.2337
# Epoch 31/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3188 - accuracy: 0.6923
# Epoch 00031: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 31ms/step - loss: 2.3198 - accuracy: 0.6907 - val_loss: 3.7336 - val_accuracy: 0.2337
# Epoch 32/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3219 - accuracy: 0.6841
# Epoch 00032: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.3201 - accuracy: 0.6846 - val_loss: 8.4494 - val_accuracy: 0.2337
# Epoch 33/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.2918 - accuracy: 0.6827
# Epoch 00033: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.2922 - accuracy: 0.6827 - val_loss: 8.2919 - val_accuracy: 0.2337
# Epoch 34/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3091 - accuracy: 0.6851
# Epoch 00034: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.3066 - accuracy: 0.6827 - val_loss: 9.6112 - val_accuracy: 0.2337
# Epoch 35/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3278 - accuracy: 0.6697
# Epoch 00035: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 31ms/step - loss: 2.3283 - accuracy: 0.6703 - val_loss: 9.8419 - val_accuracy: 0.2337
# Epoch 36/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.2801 - accuracy: 0.6841
# Epoch 00036: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.2776 - accuracy: 0.6855 - val_loss: 9.8556 - val_accuracy: 0.2337
# Epoch 37/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3298 - accuracy: 0.6736
# Epoch 00037: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.3298 - accuracy: 0.6727 - val_loss: 28.9225 - val_accuracy: 0.2337
# Epoch 38/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3147 - accuracy: 0.6981
# Epoch 00038: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.3139 - accuracy: 0.6988 - val_loss: 8.3520 - val_accuracy: 0.2337
# Epoch 39/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.2924 - accuracy: 0.6673
# Epoch 00039: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.2927 - accuracy: 0.6684 - val_loss: 9.5429 - val_accuracy: 0.2337
# Epoch 40/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3139 - accuracy: 0.6856
# Epoch 00040: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.3093 - accuracy: 0.6846 - val_loss: 2.6453 - val_accuracy: 0.3333
# Epoch 41/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3236 - accuracy: 0.6957
# Epoch 00041: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.3263 - accuracy: 0.6941 - val_loss: 2.6736 - val_accuracy: 0.3333
# Epoch 42/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.2852 - accuracy: 0.6947
# Epoch 00042: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.2830 - accuracy: 0.6941 - val_loss: 2.7944 - val_accuracy: 0.3831
# Epoch 43/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3103 - accuracy: 0.6856
# Epoch 00043: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.3084 - accuracy: 0.6865 - val_loss: 3.1979 - val_accuracy: 0.3333
# Epoch 44/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3212 - accuracy: 0.6846
# Epoch 00044: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 30ms/step - loss: 2.3200 - accuracy: 0.6836 - val_loss: 3.0513 - val_accuracy: 0.3333
# Epoch 45/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.2955 - accuracy: 0.6899
# Epoch 00045: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 31ms/step - loss: 2.2947 - accuracy: 0.6903 - val_loss: 3.0498 - val_accuracy: 0.2337
# Epoch 46/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3066 - accuracy: 0.6885
# Epoch 00046: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 32ms/step - loss: 2.3054 - accuracy: 0.6879 - val_loss: 2.6258 - val_accuracy: 0.3333
# Epoch 47/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3243 - accuracy: 0.6990
# Epoch 00047: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 31ms/step - loss: 2.3256 - accuracy: 0.6983 - val_loss: 2.3697 - val_accuracy: 0.3831
# Epoch 48/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.2931 - accuracy: 0.6779
# Epoch 00048: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 31ms/step - loss: 2.2899 - accuracy: 0.6789 - val_loss: 2.9406 - val_accuracy: 0.2337
# Epoch 49/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3090 - accuracy: 0.6812
# Epoch 00049: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 31ms/step - loss: 2.3076 - accuracy: 0.6817 - val_loss: 3.8171 - val_accuracy: 0.2337
# Epoch 50/50
# 65/66 [============================>.] - ETA: 0s - loss: 2.3253 - accuracy: 0.6803
# Epoch 00050: val_accuracy did not improve from 0.38314
# 66/66 [==============================] - 2s 31ms/step - loss: 2.3241 - accuracy: 0.6793 - val_loss: 3.2541 - val_accuracy: 0.3333

# %%
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.ylim([0, 10])
plt.show()
